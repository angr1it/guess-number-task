# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
from sqlalchemy.sql import text
# Out:
# /tmp/ipykernel_32950/428842187.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %% [markdown]
# ### Create schema and test

# %%
# run ```docker-compose --profile hw_dbs up``` to raise the db
engine = create_engine('postgresql://postgres:admin@master_ds_dbs_postgre:5432/hw2')
if not database_exists(engine.url):
    create_database(engine.url)

database_exists(engine.url)
# Out:
# True

# %%
tables = {
    "customer": """CREATE TABLE customer (
      customer_id serial primary key,
      first_name varchar(32) not null,
      last_name varchar(32),
      gender varchar(6) not null,
      dob date,
      job_title varchar(64),
      job_industry_category varchar(64),
      wealth_segment varchar(32) not null,
      deceased_indicator char(1) not null,
      owns_car boolean not null,
      address text not null,
      postcode char(4) not null,
      state varchar(32) not null,
      country varchar(32) not null,
      property_valuation int not null
    )
    """,

    "transaction": """CREATE TABLE transaction (
      transaction_id serial primary key,
      customer_id serial,
      product_id serial not null,
      transaction_date date,
      online_order bool,
      order_status varchar(16),
      brand varchar(32),
      product_line varchar(16),
      product_class varchar(16),
      product_size varchar(16),
      list_price numeric,
      standard_cost numeric
    )
    """
}
with engine.connect() as con:
    for table, create in tables.items():
        con.execute(text(f"DROP TABLE IF EXISTS {table} CASCADE"))
        con.execute(text(create))
    con.commit()

# %%
# %load_ext sql

# %%
customer = pd.read_csv('./datasets/customer.csv', sep=';')
transaction = pd.read_csv('./datasets/transaction.csv', sep=';')
customer.rename(columns={'DOB': 'dob'}, inplace=True)

customer.head(2)
# Out:
#    customer_id first_name  last_name gender         dob  \
# 0            1    Laraine  Medendorp      F  1953-10-12
# 1            2        Eli    Bockman   Male  1980-12-16
#
#                 job_title job_industry_category wealth_segment  \
# 0     Executive Secretary                Health  Mass Customer
# 1  Administrative Officer    Financial Services  Mass Customer
#
#   deceased_indicator owns_car              address  postcode            state  \
# 0                  N      Yes   060 Morning Avenue      2016  New South Wales
# 1                  N      Yes  6 Meadow Vale Court      2153  New South Wales
#
#      country  property_valuation
# 0  Australia                  10
# 1  Australia                  10

# %%
transaction.head(2)
# Out:
#    transaction_id  product_id  customer_id transaction_date online_order  \
# 0               1           2         2950       25.02.2017        False
# 1               2           3         3120       21.05.2017         True
#
#   order_status          brand product_line product_class product_size  \
# 0     Approved          Solex     Standard        medium       medium
# 1     Approved  Trek Bicycles     Standard        medium        large
#
#   list_price standard_cost
# 0      71,49         53,62
# 1    2091,47        388,92

# %%
transaction['transaction_date'] = pd.to_datetime(transaction['transaction_date'])
transaction['list_price'] = pd.to_numeric(transaction['list_price'].str.replace(',', '.'))
transaction['standard_cost'] = pd.to_numeric(transaction['standard_cost'].str.replace(',', '.'))
# Out:
# /tmp/ipykernel_32950/4011403136.py:1: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   transaction['transaction_date'] = pd.to_datetime(transaction['transaction_date'])

# %%
customer.to_sql('customer', con=engine, index=False, if_exists='append')
transaction.to_sql('transaction', con=engine, index=False, if_exists='append', )
# Out:
# 1000

# %%
# %sql postgresql://postgres:admin@master_ds_dbs_postgre:5432/hw2

# %%
# %%sql
# SELECT * FROM customer LIMIT 10;
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 10 rows affected.
# [(1, 'Laraine', 'Medendorp', 'F', datetime.date(1953, 10, 12), 'Executive Secretary', 'Health', 'Mass Customer', 'N', True, '060 Morning Avenue', '2016', 'New South Wales', 'Australia', 10),
#  (2, 'Eli', 'Bockman', 'Male', datetime.date(1980, 12, 16), 'Administrative Officer', 'Financial Services', 'Mass Customer', 'N', True, '6 Meadow Vale Court', '2153', 'New South Wales', 'Australia', 10),
#  (3, 'Arlin', 'Dearle', 'Male', datetime.date(1954, 1, 20), 'Recruiting Manager', 'Property', 'Mass Customer', 'N', True, '0 Holy Cross Court', '4211', 'QLD', 'Australia', 9),
#  (4, 'Talbot', None, 'Male', datetime.date(1961, 10, 3), None, 'IT', 'Mass Customer', 'N', False, '17979 Del Mar Point', '2448', 'New South Wales', 'Australia', 4),
#  (5, 'Sheila-kathryn', 'Calton', 'Female', datetime.date(1977, 5, 13), 'Senior Editor', None, 'Affluent Customer', 'N', True, '9 Oakridge Court', '3216', 'VIC', 'Australia', 9),
#  (6, 'Curr', 'Duckhouse', 'Male', datetime.date(1966, 9, 16), None, 'Retail', 'High Net Worth', 'N', True, '4 Delaware Trail', '2210', 'New South Wales', 'Australia', 9),
#  (7, 'Fina', 'Merali', 'Female', datetime.date(1976, 2, 23), None, 'Financial Services', 'Affluent Customer', 'N', True, '49 Londonderry Lane', '2650', 'New South Wales', 'Australia', 4),
#  (8, 'Rod', 'Inder', 'Male', datetime.date(1962, 3, 30), 'Media Manager I', None, 'Mass Customer', 'N', False, '97736 7th Trail', '2023', 'New South Wales', 'Australia', 12),
#  (9, 'Mala', 'Lind', 'Female', datetime.date(1973, 3, 10), 'Business Systems Development Analyst', 'Argiculture', 'Affluent Customer', 'N', True, '93405 Ludington Park', '3044', 'VIC', 'Australia', 8),
#  (10, 'Fiorenze', 'Birdall', 'Female', datetime.date(1988, 10, 11), 'Senior Quality Engineer', 'Financial Services', 'Mass Customer', 'N', True, '44339 Golden Leaf Alley', '4557', 'QLD', 'Australia', 4)]

# %%
# %%sql
# SELECT * FROM transaction LIMIT 10;
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 10 rows affected.
# [(1, 2950, 2, datetime.date(2017, 2, 25), False, 'Approved', 'Solex', 'Standard', 'medium', 'medium', Decimal('71.49'), Decimal('53.62')),
#  (2, 3120, 3, datetime.date(2017, 5, 21), True, 'Approved', 'Trek Bicycles', 'Standard', 'medium', 'large', Decimal('2091.47'), Decimal('388.92')),
#  (3, 402, 37, datetime.date(2017, 10, 16), False, 'Approved', 'OHM Cycles', 'Standard', 'low', 'medium', Decimal('1793.43'), Decimal('248.82')),
#  (4, 3135, 88, datetime.date(2017, 8, 31), False, 'Approved', 'Norco Bicycles', 'Standard', 'medium', 'medium', Decimal('1198.46'), Decimal('381.1')),
#  (5, 787, 78, datetime.date(2017, 10, 1), True, 'Approved', 'Giant Bicycles', 'Standard', 'medium', 'large', Decimal('1765.3'), Decimal('709.48')),
#  (6, 2339, 25, datetime.date(2017, 3, 8), True, 'Approved', 'Giant Bicycles', 'Road', 'medium', 'medium', Decimal('1538.99'), Decimal('829.65')),
#  (7, 1542, 22, datetime.date(2017, 4, 21), True, 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', Decimal('60.34'), Decimal('45.26')),
#  (8, 2459, 15, datetime.date(2017, 7, 15), False, 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', Decimal('1292.84'), Decimal('13.44')),
#  (9, 1305, 67, datetime.date(2017, 8, 10), False, 'Approved', 'Solex', 'Standard', 'medium', 'large', Decimal('1071.23'), Decimal('380.74')),
#  (10, 3262, 12, datetime.date(2017, 8, 30), True, 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', Decimal('1231.15'), Decimal('161.6'))]

# %% [markdown]
# ### Tasks

# %% [markdown]
# #### Task 1
#
# (1 балл) Вывести все уникальные бренды, у которых стандартная стоимость выше 1500 долларов.

# %%
# %%sql
#
# SELECT DISTINCT brand
# FROM transaction
# WHERE standard_cost > 1500;
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 4 rows affected.
# [('OHM Cycles',), ('Trek Bicycles',), ('Solex',), ('Giant Bicycles',)]

# %% [markdown]
# #### Task 2
#
# (1 балл) Вывести все подтвержденные транзакции за период '2017-04-01' по '2017-04-09' включительно.

# %%
# %%sql
#
# SELECT *
# FROM transaction
# WHERE transaction_date BETWEEN '2017-04-01' AND '2017-04-09'
#     AND order_status = 'Approved'
# LIMIT 10; --добавил, т.к. ipython-sql отправляет все 551 наблюдений в output; не нашел как ограничить на уровне kernel.
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 10 rows affected.
# [(17, 2426, 79, datetime.date(2017, 4, 3), False, 'Approved', 'Norco Bicycles', 'Standard', 'medium', 'medium', Decimal('1555.58'), Decimal('818.01')),
#  (19, 2268, 54, datetime.date(2017, 4, 6), True, 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', Decimal('1292.84'), Decimal('13.44')),
#  (23, 2001, 37, datetime.date(2017, 4, 8), True, 'Approved', 'OHM Cycles', 'Standard', 'low', 'medium', Decimal('1793.43'), Decimal('248.82')),
#  (83, 3398, 0, datetime.date(2017, 4, 1), True, 'Approved', 'OHM Cycles', 'Standard', 'medium', 'medium', Decimal('235.63'), Decimal('125.07')),
#  (89, 2682, 0, datetime.date(2017, 4, 4), True, 'Approved', 'OHM Cycles', 'Road', 'high', 'large', Decimal('12.01'), Decimal('7.21')),
#  (126, 773, 53, datetime.date(2017, 4, 1), False, 'Approved', 'OHM Cycles', 'Standard', 'medium', 'medium', Decimal('795.34'), Decimal('101.58')),
#  (146, 3261, 41, datetime.date(2017, 4, 6), True, 'Approved', 'Solex', 'Road', 'medium', 'medium', Decimal('416.98'), Decimal('312.74')),
#  (154, 3383, 3, datetime.date(2017, 4, 6), True, 'Approved', 'Trek Bicycles', 'Standard', 'medium', 'large', Decimal('2091.47'), Decimal('388.92')),
#  (220, 1502, 10, datetime.date(2017, 4, 9), True, 'Approved', 'WeareA2B', 'Touring', 'medium', 'medium', Decimal('1466.68'), Decimal('363.25')),
#  (228, 821, 13, datetime.date(2017, 4, 4), True, 'Approved', 'Solex', 'Standard', 'medium', 'medium', Decimal('1163.89'), Decimal('589.27'))]

# %% [markdown]
# #### Task 3
#
# (1 балл) Вывести все профессии у клиентов из сферы IT или Financial Services, которые начинаются с фразы 'Senior'.

# %%
# %%sql
#
# SELECT DISTINCT c.job_title
# FROM customer c
# INNER JOIN transaction t ON c.customer_id = t.customer_id
# WHERE c.job_industry_category IN ('IT', 'Financial Services')
# AND c.job_title LIKE 'Senior%';
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 6 rows affected.
# [('Senior Sales Associate',),
#  ('Senior Financial Analyst',),
#  ('Senior Editor',),
#  ('Senior Quality Engineer',),
#  ('Senior Developer',),
#  ('Senior Cost Accountant',)]

# %% [markdown]
# #### Task 4
#
# (1 балл) Вы|вести все бренды, которые закупают клиенты, работающие в сфере Financial Services

# %%
# %%sql
#
# SELECT DISTINCT t.brand
# FROM transaction t
# INNER JOIN customer c ON t.customer_id = c.customer_id
# WHERE c.job_industry_category = 'Financial Services';
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 7 rows affected.
# [(None,),
#  ('Trek Bicycles',),
#  ('WeareA2B',),
#  ('Solex',),
#  ('Giant Bicycles',),
#  ('OHM Cycles',),
#  ('Norco Bicycles',)]

# %% [markdown]
# #### Task 5
#
# (1 балл) Вывести 10 клиентов, которые оформили онлайн-заказ продукции из брендов 'Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles'.

# %%
# %%sql
#
# SELECT DISTINCT c.customer_id, c.first_name, c.last_name
# FROM transaction t
# INNER JOIN customer c ON t.customer_id = c.customer_id
# WHERE t.online_order = 'TRUE'
#     AND t.brand IN ('Giant Bicycles', 'Norco Bicycles', 'Trek Bicycles')
# LIMIT 10;
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 10 rows affected.
# [(742, 'Dexter', 'Robelin'),
#  (3123, 'Tina', 'Riggulsford'),
#  (20, 'Basile', 'Firth'),
#  (1894, 'Patten', 'Laytham'),
#  (3426, 'Ron', 'Dilon'),
#  (1179, 'Kerry', 'Pashenkov'),
#  (3491, 'Leanna', 'Cromb'),
#  (2201, 'Trisha', 'Basset'),
#  (3095, 'Joachim', None),
#  (1521, 'Pernell', 'Duffett')]

# %% [markdown]
# #### Task 6
#
# (1 балл) Вывести всех клиентов, у которых нет транзакций.

# %%
# %%sql
#
# SELECT c.customer_id, c.first_name, c.last_name
# FROM customer c
# LEFT JOIN transaction t ON c.customer_id = t.customer_id
# WHERE t.transaction_id IS NULL
# LIMIT 10; -- аналогично task 2; получаем 507 строк без ограничения
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 10 rows affected.
# [(3565, 'Charyl', 'Pottiphar'),
#  (3535, 'Bren', 'Dabbes'),
#  (3647, 'Carlyle', 'Frape'),
#  (3903, 'Dayna', 'Cawthera'),
#  (3519, 'Aldus', 'Kenningley'),
#  (3612, 'Normand', 'Matous'),
#  (3652, 'Aldrich', 'Camble'),
#  (3949, 'Costa', 'Sleightholm'),
#  (3704, 'Haslett', 'Ropars'),
#  (3989, 'Nicolas', 'Burdass')]

# %% [markdown]
# #### Task 7
#
# (2 балла) Вывести всех клиентов из IT, у которых транзакции с максимальной стандартной стоимостью.

# %%
# %%sql
#
# SELECT c.customer_id, c.first_name, c.last_name, t.standard_cost
# FROM customer c
# INNER JOIN transaction t ON c.customer_id = t.customer_id
# WHERE c.job_industry_category = 'IT'
#     AND t.standard_cost = (
#         SELECT max(standard_cost)
#         FROM transaction
#     );
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 9 rows affected.
# [(3473, 'Sanderson', 'Alloway', Decimal('1759.85')),
#  (893, 'Gibby', 'Fearnley', Decimal('1759.85')),
#  (3151, 'Thorn', 'Choffin', Decimal('1759.85')),
#  (34, 'Jephthah', 'Bachmann', Decimal('1759.85')),
#  (2913, 'Padraic', 'Bonnar', Decimal('1759.85')),
#  (1918, 'Devin', 'Sandeson', Decimal('1759.85')),
#  (1672, 'Sharla', 'Creebo', Decimal('1759.85')),
#  (975, 'Goldarina', 'Rzehorz', Decimal('1759.85')),
#  (1773, 'Nickolas', 'Guittet', Decimal('1759.85'))]

# %% [markdown]
# #### Task 8
#
# (2 балла) Вывести всех клиентов из сферы IT и Health, у которых есть подтвержденные транзакции за период '2017-07-07' по '2017-07-17'.

# %%
# %%sql
#
# SELECT DISTINCT c.customer_id, c.first_name, c.last_name, c.job_industry_category
# FROM customer c
# INNER JOIN transaction t ON c.customer_id = t.customer_id
# WHERE c.job_industry_category in ('IT', 'Health')
#     AND t.transaction_date BETWEEN '2017-07-07' AND '2017-07-17'
#     AND t.order_status = 'Approved';
# Out:
#  * postgresql://postgres:***@master_ds_dbs_postgre:5432/hw2
# 115 rows affected.
# [(22, 'Deeanne', 'Durtnell', 'IT'),
#  (28, 'Fee', 'Zellmer', 'Health'),
#  (41, 'Basilius', 'Coupe', 'Health'),
#  (47, 'Matthew', 'Jeaycock', 'Health'),
#  (104, 'Odille', 'Panketh', 'Health'),
#  (235, 'Leona', 'Phateplace', 'Health'),
#  (239, 'Wells', 'Pressman', 'Health'),
#  (249, "D'arcy", 'Slay', 'IT'),
#  (289, 'Modestia', 'Lithgow', 'Health'),
#  (290, 'Giorgio', 'Kevane', 'IT'),
#  (300, 'Malachi', 'Hadcroft', 'Health'),
#  (320, 'Aldous', 'Cubin', 'Health'),
#  (331, 'Ford', 'Groucock', 'Health'),
#  (338, 'Hilliary', 'Littrell', 'Health'),
#  (350, 'Carmela', 'Jesper', 'Health'),
#  (382, 'Issiah', 'Fardell', 'Health'),
#  (414, 'Thorin', 'Grimoldby', 'Health'),
#  (424, 'Dennie', 'Eunson', 'Health'),
#  (428, 'Freida', 'Everil', 'Health'),
#  (503, 'Burr', 'Gerb', 'Health'),
#  (526, 'Ardelle', None, 'Health'),
#  (579, 'Cathlene', 'Bellas', 'Health'),
#  (590, 'Ddene', 'Burleton', 'Health'),
#  (612, 'Grange', 'Skillington', 'Health'),
#  (661, 'Cinderella', 'Haslen', 'IT'),
#  (679, 'Yolande', 'Whild', 'Health'),
#  (682, 'Ole', 'Euplate', 'Health'),
#  (685, 'Booth', 'Birkin', 'IT'),
#  (694, 'Lilith', 'Lanning', 'Health'),
#  (708, 'Idalina', 'Wilcot', 'IT'),
#  (712, 'Norine', 'Antonik', 'IT'),
#  (722, 'Stewart', 'Brosoli', 'IT'),
#  (753, 'Josy', 'St. Quentin', 'Health'),
#  (759, 'Mitchel', 'Schimek', 'Health'),
#  (769, 'Cameron', 'Letherbury', 'IT'),
#  (779, 'Maddy', 'Larrat', 'Health'),
#  (788, 'Gregg', 'Townsend', 'Health'),
#  (872, 'Suki', 'Ivachyov', 'IT'),
#  (886, 'Dawna', 'McCullen', 'Health'),
#  (892, 'Conroy', 'Healy', 'IT'),
#  (893, 'Gibby', 'Fearnley', 'IT'),
#  (936, 'Raffaello', 'Godleman', 'Health'),
#  (949, 'Jarid', 'Grebner', 'Health'),
#  (950, 'Bret', 'Ivakhnov', 'IT'),
#  (973, 'Annabella', 'Hebron', 'Health'),
#  (1005, 'Kalila', 'Birtwistle', 'IT'),
#  (1024, 'Rhodia', "D'Onise", 'Health'),
#  (1044, 'Frederico', 'Whilder', 'Health'),
#  (1076, 'Siegfried', 'Trattles', 'Health'),
#  (1091, 'Keith', 'Housden', 'Health'),
#  (1095, 'Emelda', 'Gerler', 'Health'),
#  (1166, 'Fannie', 'Devil', 'Health'),
#  (1174, 'Shellysheldon', 'Gooderridge', 'IT'),
#  (1189, 'Mart', 'Bazoche', 'Health'),
#  (1231, 'Aloisia', 'Shawel', 'Health'),
#  (1237, 'Junia', 'Humerstone', 'Health'),
#  (1328, 'Stavro', 'Gargett', 'IT'),
#  (1337, 'Damara', 'Wheatland', 'Health'),
#  (1343, 'Creight', 'Deery', 'Health'),
#  (1376, 'Pail', None, 'Health'),
#  (1394, 'Freemon', 'Perago', 'Health'),
#  (1489, 'Mead', 'Wollard', 'Health'),
#  (1516, 'Ham', 'Pietrusiak', 'IT'),
#  (1538, 'Ahmed', 'Edmondson', 'Health'),
#  (1542, 'Sanders', 'Fernyhough', 'Health'),
#  (1555, 'Marcello', 'Spenclay', 'Health'),
#  (1578, 'Andreas', 'Bazely', 'Health'),
#  (1585, 'Stillman', 'Sackur', 'Health'),
#  (1683, 'Brenn', 'Bacon', 'IT'),
#  (1693, 'Ring', 'Birchall', 'Health'),
#  (1760, 'Kelsy', 'Barrowcliff', 'Health'),
#  (1836, 'Rochella', 'Harce', 'Health'),
#  (1862, 'Daron', 'Umpleby', 'Health'),
#  (1907, 'Lind', 'Dredge', 'Health'),
#  (1929, 'Elka', 'Crossgrove', 'Health'),
#  (1952, 'Patrica', 'Donativo', 'Health'),
#  (1956, 'Omero', 'Murra', 'Health'),
#  (2000, 'Kain', 'Rene', 'IT'),
#  (2024, 'Elinor', 'Biggerstaff', 'IT'),
#  (2205, 'Birk', 'Elphey', 'IT'),
#  (2210, 'Kirby', 'Cameron', 'Health'),
#  (2235, 'Maxine', 'Cauldwell', 'Health'),
#  (2285, 'Maritsa', 'Bellison', 'Health'),
#  (2317, 'Alwin', 'Cuberley', 'Health'),
#  (2337, 'Odilia', 'Bick', 'Health'),
#  (2341, 'Caterina', 'Scedall', 'IT'),
#  (2366, 'Idette', 'Mapam', 'Health'),
#  (2391, 'Corny', 'Millott', 'Health'),
#  (2442, 'Odie', 'Enrrico', 'Health'),
#  (2463, 'Krystle', 'Jovicevic', 'Health'),
#  (2490, 'Clint', 'Krause', 'Health'),
#  (2516, 'Zoe', 'Kiddye', 'Health'),
#  (2610, 'Arliene', 'Bartolijn', 'IT'),
#  (2684, 'Erastus', 'Payley', 'Health'),
#  (2690, 'Sissie', 'Giordano', 'Health'),
#  (2701, 'Ileana', 'Timms', 'Health'),
#  (2717, 'Frederic', 'McGown', 'Health'),
#  (2782, 'Gillian', 'Scrimshire', 'IT'),
#  (2881, 'Ezra', 'Steffan', 'Health'),
#  (2953, 'Hector', 'Carwithan', 'Health'),
#  (2973, 'Torr', 'Mintram', 'Health'),
#  (3070, 'Malissia', 'Minthorpe', 'Health'),
#  (3105, 'Bryn', 'Rycraft', 'Health'),
#  (3109, 'Jeralee', 'Domleo', 'Health'),
#  (3151, 'Thorn', 'Choffin', 'IT'),
#  (3166, 'Bronson', 'Plowman', 'Health'),
#  (3169, 'Maxim', 'Chavrin', 'IT'),
#  (3173, 'Angelo', None, 'Health'),
#  (3211, 'Betsy', 'Cosh', 'Health'),
#  (3225, 'Durante', 'Reddan', 'Health'),
#  (3255, 'Sutherlan', 'Truin', 'IT'),
#  (3288, 'Fair', 'Dewen', 'IT'),
#  (3360, 'Joelie', 'Sherlaw', 'Health'),
#  (3365, 'Karlens', 'Chaffyn', 'IT'),
#  (3482, 'Roch', 'Rilston', 'Health')]
